# %% [markdown]
# # import statements
#
# these need to be added to every file that we want to use spacy, randomness etc in

# %%
import random

# %%
import sys
# !conda install -c conda-forge -y --prefix {sys.prefix} spacy
# Out:
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): conda.anaconda.org:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/noarch/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/noarch/current_repodata.json HTTP/1.1" 304 0
# \ DEBUG:urllib3.connectionpool:https://conda.anaconda.org:443 "GET /conda-forge/noarch/current_repodata.json HTTP/1.1" 200 None
# ...

# %%
import spacy

# !{sys.executable} -m spacy download en_core_web_md
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 7.9 MB/s eta 0:00:0000:0100:01m
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
nlp = spacy.load('en_core_web_md')

# %% [markdown]
# ## everything above this line is REQUIRED SETUP

# %% [markdown]
# ---
# # everything below this line is about reading files

# %%
text = open('mini-twilight.txt').read()
processedText = nlp(text)

# %%
processedText = nlp(open('mini-twilight.txt').read())

# %%
full_twilight = open('twilight.txt').read()
processed_full_twilight = nlp(full_twilight)

# %% [markdown]
# # now everything is set up! including reading text files

# %% [markdown]
# # on to review:
#
# ## variables
# ## if statements / conditionals
# * remember that == is used inside the conditional () instead of =
# ## for loop

# %%
# anatomy of a for loop
# 1) for -- required syntax
# 2) item -- temporary variable that only exists in the for loop
# 3) in -- required syntax
# 4) processed_full_twilight -- the data structure we are looking through
# https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

for item in processed_full_twilight:
    if(item.tag_ == 'UH'):
        print(item.text)
# Out:
# hi
# goodbyes
# Well
# No
# Well
# Well
# no
# Well
# Wow
# Well
# well
# Wow
# Well
# Wow
# Well
# exactiy
# Yes
# Oh
# No
# Hi
# Yes
# No
# hi
# Hey
# Well
# Sure
# Wow
# No
# Sure
# okay
# No
# well
# Oh
# No
# No
# Oh
# No
# No
# Oh
# Yeah
# Yes
# Well
# No
# No
# Ow
# No
# No
# Please
# wow
# Well
# Oh
# no
# No
# no
# Oh
# well
# yes
# No
# Um
# No
# Well
# no
# well
# yes
# No
# Sorry
# no
# Yeah
# No
# Hey
# Uh
# Well
# yeah
# Oh
# Well
# Oh
# Yeah
# Okay
# Well
# Yeah
# Well
# Yes
# Oh
# okay
# No
# Oh
# please
# Well
# Oh
# Well
# No
# Yes
# Well
# Yes
# No
# Yes
# No
# No
# Yes
# Please
# Er
# Please
# Um
# well
# Oh
# No
# Well
# Okay
# please
# Oh
# no
# Yes
# please
# Yes
# please
# Wow
# No
# Please
# No
# No
# Please
# please
# Hey
# Oh
# my
# Ha
# ha
# Oh
# no
# Well
# Yeah
# Yes
# No
# Okay
# Well
# No
# Yes
# Yes
# Oh
# sorry
# No
# Oh
# well
# Yeah
# Oh
# Nope
# Sure
# No
# Oh
# No
# No
# Wow
# Yeah
# No
# Sorry
# Yes
# Oh
# Oh
# Oops
# Oh
# Well
# Yes
# well
# ...

# %% [markdown]
# # creating dadaist poem
# https://www.writing.upenn.edu/~afilreis/88v/tzara.html
#
#  How to Make a Dadaist Poem
# (method of Tristan Tzara)
#
# To make a Dadaist poem:
#
# * Take a newspaper.
# * Take a pair of scissors.
# * Choose an article as long as you are planning to make your poem.
# * Cut out the article.
# * Then cut out each of the words that make up this article and put them in a bag.
# * Shake it gently.
# * Then take out the scraps one after the other in the order in which they left the bag.
# * Copy conscientiously.
# * The poem will be like you.
# * And here are you a writer, infinitely original and endowed with a sensibility that is charming though beyond the understanding of the vulgar.
#
# --Tristan Tzara

# %%
twilight_sentences = []

twilight_sentences = list(processed_full_twilight.sents)

random.choice(twilight_sentences)
# Out:
# "Yes."
#
# "Get dressed — I'll wait here."

# %%
mini_twilight_sent = list(processedText.sents)

mini_twilight_sent
# Out:
# [My mother drove me to the airport with the windows rolled down.,
#  It was seventy-five degrees in
#  Phoenix, the sky a perfect, cloudless blue.,
#  I was wearing my favorite shirt — sleeveless, white eyelet
#  lace; I was wearing it as a farewell gesture.,
#  My carry-on item was a parka.]

# %%
count = 0
for s in mini_twilight_sent:
    print(str(count) + " " + s.text + '\n\n')
    count = count + 1
# Out:
# 0 My mother drove me to the airport with the windows rolled down.
#
#
# 1 It was seventy-five degrees in
# Phoenix, the sky a perfect, cloudless blue.
#
#
# 2 I was wearing my favorite shirt — sleeveless, white eyelet
# lace; I was wearing it as a farewell gesture.
#
#
# 3 My carry-on item was a parka.

# %%
dada_sent = []
num_gen = []

maxsent = len(mini_twilight_sent) - 1

random.randint(0, maxsent)

while len(dada_sent) != 4:
    num = random.randint(0, maxsent)
    if num not in num_gen:
        num_gen.append(num)
        dada_sent.append(mini_twilight_sent[num])
        
for s in dada_sent:
    print(s.text + '\n\n')
# Out:
# It was seventy-five degrees in
# Phoenix, the sky a perfect, cloudless blue.
#
#
# My carry-on item was a parka.
#
#
# My mother drove me to the airport with the windows rolled down.
#
#
# I was wearing my favorite shirt — sleeveless, white eyelet
# lace; I was wearing it as a farewell gesture.
